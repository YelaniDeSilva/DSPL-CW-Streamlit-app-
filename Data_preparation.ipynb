# %% [markdown]
# <a href="https://colab.research.google.com/github/YelaniDeSilva/DSPL-CW-Streamlit-app-/blob/main/Data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/education indicators.csv')

# %%
df.head()
# Out:
#   Country Name Country ISO3  Year  \
# 0    Sri Lanka          LKA  2010
# 1    Sri Lanka          LKA  2005
# 2    Sri Lanka          LKA  2000
# 3    Sri Lanka          LKA  1995
# 4    Sri Lanka          LKA  1990
#
#                                       Indicator Name Age range     Indicator   \
# 0  Barro-Lee: Percentage of population age 15-19 ...      15-19  No education
# 1  Barro-Lee: Percentage of population age 15-19 ...      15-19  No education
# 2  Barro-Lee: Percentage of population age 15-19 ...      15-19  No education
# 3  Barro-Lee: Percentage of population age 15-19 ...      15-19  No education
# 4  Barro-Lee: Percentage of population age 15-19 ...      15-19  No education
#
#   Indicator Code  Value
# 0           NOED   0.80
# 1           NOED   2.12
# 2           NOED   3.20
# 3           NOED   2.18
# 4           NOED   3.33

# %%
print(df.dtypes)
# Out:
# Country Name       object
# Country ISO3       object
# Year                int64
# Indicator Name     object
# Age range          object
# Indicator          object
# Indicator Code     object
# Value             float64
# dtype: object
